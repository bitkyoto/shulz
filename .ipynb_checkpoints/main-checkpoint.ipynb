# %% [markdown]
# Создать функцию, генерирующую гармонический сигнал по правилу (1): y = A*cos(2Pi*f*t + fi0), где A - амплитуда, f - частота, t - время, fi0 - начальная фаза.
#
# Создать функцию, генерирующую периодический сигнал, изменяя в правиле (1) значение частоту в диапазоне от 0 до Pi с шагом 0.1. Исследуйте  изменение графика относительно начального.
#
# Провести аналогичные исследования, изменяя значения амплитуды в диапазоне от 0 до 2. Шаг 0.1
#
# Полученные три функции сложить и вывести результат.
#
# Закончить исследование в двумерном пространстве.

# %%
import math
import numpy as np
import matplotlib.pyplot as plt

def y(A, f, t, phi0):
    return A * math.cos(2*math.pi*f*t + phi0)

def generate_periodic_signal():    
    # Параметры сигнала
    A = 1
    f = 1
    phi0 = 0
    t = np.linspace(0, 2, 50)
    values = []
    # Генерация сигнала
    for dt in t:
        values.append(y(A, f, dt, phi0))
    return t, values
# Визуализация сигнала
t, values = generate_periodic_signal()
plt.plot(t, values)
plt.title('Гармонический сигнал')
plt.xlabel('Время')
plt.ylabel('y(x)')
plt.show()

# %%
def generate_periodic_signal_varying_frequency(): 
    # Параметры сигнала
    A = 1
    phi0 = 0
    f = 0
    t = np.linspace(0, 2, 50)
    values = []
    # Генерация сигнала
    for dt in t:
        values.append(y(A, f, dt, phi0))
        if f <= math.pi: f += 0.1
    return t, values
              
t, values = generate_periodic_signal_varying_frequency()
plt.plot(t, values)
plt.title('Периодические сигналы с изменяющейся частотой')
plt.xlabel('Время')
plt.ylabel('y(x)')
plt.show()

# %%
def generate_periodic_signal_varying_amplitude():
    A = 0
    phi0 = 0
    f = 1
    t = np.linspace(0, 2, 50)
    values = []
    # Генерация сигнала
    for dt in t:
        values.append(y(A, f, dt, phi0))
        if A <= 2: A += 0.1
    return t, values


t, values = generate_periodic_signal_varying_amplitude()
plt.plot(t, values)
plt.title('Периодические сигналы с изменяющейся амплитудой')
plt.xlabel('Время')
plt.ylabel('y(x)')
plt.show()

# %%
def generate_combined_signal():
    t1, v1 = generate_periodic_signal()
    t2, v2 = generate_periodic_signal_varying_frequency()
    t3, v3 = generate_periodic_signal_varying_amplitude()
    result = np.array(v1) + np.array(v2) + np.array(v3)
    return t1, result
t, values = generate_combined_signal()
plt.plot(t, values)
plt.title('Сложенные графики')
plt.xlabel('Время')
plt.ylabel('y(x)')

plt.show()

# %% [markdown]
# Перейти в трехмерное.
#
# Пусть плоскость первого сигнала лежит вдоль оси Z. Плоскость второго сигнала повернуть на <свой порядковый номер в группе> градусов относительно первой. Плоскость третьего - на <свой порядковый номер в группе> градусов относительно второй.  Направление поворота выберите сами (относительно оси x, y или z).
#
# Сложить сигналы. Вывести  результат.
#
# Вычислить амплитуду, частоту и фазу результирующего сигнала с использованием быстрого преобразования Фурье (FFT).
#
# Построить амплитудный спектр полученного сигнала.
#
# Проанализировать результат.

# %%
def rotate_signal(signal, angle, axis):
    rotation_matrix = np.eye(3)
    if axis == 'x':
        rotation_matrix = np.array([
            [1, 0, 0],
            [0, np.cos(angle), -np.sin(angle)],
            [0, np.sin(angle), np.cos(angle)]
        ])
    elif axis == 'y':
        rotation_matrix = np.array([
            [np.cos(angle), 0, np.sin(angle)],
            [0, 1, 0],
            [-np.sin(angle), 0, np.cos(angle)]
        ])
    elif axis == 'z':
        rotation_matrix = np.array([
            [np.cos(angle), -np.sin(angle), 0],
            [np.sin(angle), np.cos(angle), 0],
            [0, 0, 1]
        ])
    rotated_signal = np.dot(rotation_matrix, signal)
    return rotated_signal
def generate_combined_signal():
    t1, v1 = generate_periodic_signal()
    print(v1)
    t2, v2 = generate_periodic_signal_varying_frequency()
    print(v2)
    t3, v3 = generate_periodic_signal_varying_amplitude()
    t4, v_combined = generate_combined_signal()
    # Поворот сигналов
    angle1 = np.radians(3)  # Замените 5 на ваш порядковый номер в группе
    angle2 = np.radians(6)  # Замените 5 на ваш порядковый номер в группе

    v1_rotated = rotate_signal(np.vstack((t1, v1, np.zeros_like(v1) )), np.radians(1),      'x')
    
    v2_rotated = rotate_signal(np.vstack((t2, v2, np.zeros_like(v2) )), angle1, 'x')
    v3_rotated = rotate_signal(np.vstack((t3, v3, np.zeros_like(v3) )), angle2, 'x')
    # Сложение 
    
    # combined = np.array(v1_rotated) + np.array(v2_rotated) + np.array(v3_rotated)

    return t1, v1, v2, v3, v2_rotated, v3_rotated, combined_signal

t, v1, v2, v3, v2_rotated, v3_rotated, combined_signal = generate_combined_signal()

# Визуализация результата
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot(t, v1, zs=0, zdir='y',label='s1')
ax.plot(v2_rotated[0], v2_rotated[1], v2_rotated[2], zdir='y', label='s2_rotated')
ax.plot(v3_rotated[0], v3_rotated[1], v3_rotated[2], zdir='y', label='s3_rotated')
# ax.plot(combined_signal[0],combined_signal[1],combined_signal[2], zdir='y', label='Сложенный сигнал')
ax.set_title('Сложенный сигнал в трехмерном пространстве')
ax.set_xlabel('Время')
ax.legend()
plt.show()
# Out:
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[26], line 44
#      38     # Сложение
#      39
#      40     # combined = np.array(v1_rotated) + np.array(v2_rotated) + np.array(v3_rotated)
#      42     return t1, v1, v2, v3, v2_rotated, v3_rotated, combined_signal
# ---> 44 t, v1, v2, v3, v2_rotated, v3_rotated, combined_signal = generate_combined_signal()
#      46 # Визуализация результата
#      47 fig = plt.figure()
#
# Cell In[26], line 29, in generate_combined_signal()
#      27 print(v2)
#      28 t3, v3 = generate_periodic_signal_varying_amplitude()
# ---> 29 t4, v_combined = generate_combined_signal()
#      30 # Поворот сигналов
#      31 angle1 = np.radians(3)  # Замените 5 на ваш порядковый номер в группе
#
# Cell In[26], line 29, in generate_combined_signal()
#      27 print(v2)
#      28 t3, v3 = generate_periodic_signal_varying_amplitude()
# ---> 29 t4, v_combined = generate_combined_signal()
#      30 # Поворот сигналов
#      31 angle1 = np.radians(3)  # Замените 5 на ваш порядковый номер в группе
#
#     [... skipping similar frames: generate_combined_signal at line 29 (2971 times)]
#
# Cell In[26], line 29, in generate_combined_signal()
#      27 print(v2)
#      28 t3, v3 = generate_periodic_signal_varying_amplitude()
# ---> 29 t4, v_combined = generate_combined_signal()
#      30 # Поворот сигналов
#      31 angle1 = np.radians(3)  # Замените 5 на ваш порядковый номер в группе
#
# Cell In[26], line 24, in generate_combined_signal()
#      23 def generate_combined_signal():
# ---> 24     t1, v1 = generate_periodic_signal()
#      25     print(v1)
#      26     t2, v2 = generate_periodic_signal_varying_frequency()
#
# Cell In[2], line 13, in generate_periodic_signal()
#      11 f = 1
#      12 phi0 = 0
# ---> 13 t = np.linspace(0, 2, 50)
#      14 values = []
#      15 # Генерация сигнала
#
# File ~\PycharmProjects\shulz\.venv\Lib\site-packages\numpy\_core\function_base.py:142, in linspace(start, stop, num, endpoint, retstep, dtype, axis, device)
#     138 # Use `dtype=type(dt)` to enforce a floating point evaluation:
#     139 delta = np.subtract(stop, start, dtype=type(dt))
#     140 y = _nx.arange(
#     141     0, num, dtype=dt, device=device
# --> 142 ).reshape((-1,) + (1,) * ndim(delta))
#     144 # In-place multiplication y *= delta/div is faster, but prevents
#     145 # the multiplicant from overriding what class is produced, and thus
#     146 # prevents, e.g. use of Quantities, see gh-7142. Hence, we multiply
#     147 # in place only for standard scalar types.
#     148 if div > 0:
#
# RecursionError: maximum recursion depth exceeded
